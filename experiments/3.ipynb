# %% [markdown]
# ### Imports

# %%
import os
import yaml
import polars as pl

# %% [markdown]
# ### Experiment description

# %% [markdown]
# 1. Predict ClusterID for clustering datasets
# 2. Use PointTransformer
# 3. Features = ones
# 4. Homogeneous graph

# %% [markdown]
# ### Variables

# %%
input_folder = '../../../data/nieves'
output_folder = '../../../output/nieves/expt3'
input_expt_folder = '../../../data/nieves/expt3'

# %% [markdown]
# ### Preprocess data to suitable output location

# %%
folders = [output_folder, os.path.join(input_folder, "config/expt3"), input_expt_folder]

for folder in folders:
    if not os.path.exists(folder):
        os.makedirs(folder)

# %%
# Code specific to dataset & experiment 1
root_dir = os.path.join(input_folder, "ml_data")
for file in os.listdir(root_dir):
    df = pl.read_csv(os.path.join(root_dir, file))
        
    if file.startswith('gt_'):
        df = df.rename({'':'x', '_duplicated_0':'y', 'moleculeClusterIndex': 'gt_label'})
    elif file.startswith('multiple_blinking'):
        df = df.drop(['error', 'moleculeIndex'])
        df = df.rename({'clusterIndex': 'gt_label'})
        
    # change all cluster id's which are != 0 to 1 so we can predict not clustered or clustered
    df = df.with_columns((pl.when(pl.col('gt_label') != 0)).then(1).otherwise(0).alias('gt_label'))
    
    # save 
    file_name, _ = os.path.splitext(file)
    file_name = os.path.join(input_expt_folder, file_name + '.parquet')
    df.write_parquet(file_name)

# %%
# Export config variables to file

config = {}

# The following are the names of the 
# x column, y column, z column if present, channel, frame,
# in the csvs being processed
config['x_col'] = 'x'
config['y_col'] = 'y'
config['z_col'] = None
config['channel_col'] = None #'channel'
config['frame_col'] = None # 'frame'

# The number of dimensions to consider
# If 2 only deals with x and y 
# If 3 will read in and deal with z as well (currently not fully supported)
config['dim'] = 2

# choice of which channels user wants to consider
# if null considers all
config['channel_choice'] = None

# specify string for each channel
config['channel_label'] = None
  #0: egfr
  #1: ereg

# whether to not drop the column containing
# pixel
config['drop_pixel_col'] = False

# files to include: all for everyone 
config['include_files'] = 'all' 

## Choice of input features
config['features'] = []

## GT label per loc or per FOV
config['gt_label_scope'] = 'loc'

## if gt label specified, whih channel is it in (if its label per fov then only one row has to have value), or leave as null
config['gt_label'] = "gt_label"

## specify the gt label map
config['gt_label_map'] = {0: 'unclustered', 1: 'clustered'}

yaml_save_loc = os.path.join(input_folder, 'config/expt3/preprocess.yaml')
with open(yaml_save_loc, "w") as outfile:
        yaml.dump(config, outfile)

# %%
# Run the preprocess script using this file

# !python ../src/locpix_points/scripts/preprocess.py -i ../../../data/nieves/expt3 -c ../../../data/nieves/config/expt3/preprocess.yaml -o ../../../output/nieves/expt3 -p
# Out:
# List of files which will be processed
# ['../../../data/nieves/expt3/gt_scenario_8_diffden_MoleculeList_10.parquet', '../../../data/nieves/expt3/gt_scenario_2_normal_50single_MoleculeList_43.parquet', '../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_23.parquet', '../../../data/nieves/expt3/gt_scenario_8_diffden_MoleculeList_22.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_7_diffsig_DetectionList1.parquet', '../../../data/nieves/expt3/gt_scenario_2_normal_50single_MoleculeList_7.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_9_dsigsden_new_DetectionList_38.parquet', '../../../data/nieves/expt3/gt_scenario_7_diffsig_MoleculeList_6.parquet', '../../../data/nieves/expt3/gt_scenario_4_lowden_MoleculeList_6.parquet', '../../../data/nieves/expt3/gt_scenario_0_mongrad_MoleculeList_3.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_4_lowden_DetectionList_34.parquet', '../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_19.parquet', '../../../data/nieves/expt3/gt_scenario_5_highden_MoleculeList_17.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_7_diffsig_DetectionList23.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_0_mongrad_DetectionList_34.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_6_elliptical_w_noise_DetectionList_38.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_3_normal_80single_new_DetectionList_23.parquet', '../../../data/nieves/expt3/gt_scenario_9_dsigsden_new_MoleculeList_28.parquet', '../../../data/nieves/expt3/gt_scenario_7_diffsig_MoleculeList_37.parquet', '../../../data/nieves/expt3/gt_scenario_4_lowden_MoleculeList_19.parquet', '../../../data/nieves/expt3/gt_scenario_3_normal_80single_new_MoleculeList_15.parquet', '../../../data/nieves/expt3/gt_scenario_0_mongrad_MoleculeList_50.parquet', '../../../data/nieves/expt3/gt_scenario_4_lowden_MoleculeList_27.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_8_diffden_DetectionList21.parquet', '../../../data/nieves/expt3/gt_scenario_8_diffden_MoleculeList_23.parquet', '../../../data/nieves/expt3/gt_scenario_6_elliptical_w_noise_MoleculeList_41.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_0_mongrad_DetectionList_7.parquet', '../../../data/nieves/expt3/gt_scenario_7_diffsig_MoleculeList_34.parquet', '../../../data/nieves/expt3/gt_scenario_0_mongrad_MoleculeList_12.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_8_diffden_DetectionList40.parquet', '../../../data/nieves/expt3/gt_scenario_4_lowden_MoleculeList_28.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_5_highden_DetectionList_14.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_4_lowden_DetectionList_25.parquet', '../../../data/nieves/expt3/gt_scenario_6_elliptical_w_noise_MoleculeList_2.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_6_elliptical_w_noise_DetectionList_33.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_0_mongrad_DetectionList_48.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_5_highden_DetectionList_24.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_5_highden_DetectionList_37.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_6_elliptical_w_noise_DetectionList_34.parquet', '../../../data/nieves/expt3/gt_scenario_2_normal_50single_MoleculeList_49.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_6_elliptical_w_noise_DetectionList_10.parquet', '../../../data/nieves/expt3/gt_scenario_5_highden_MoleculeList_38.parquet', '../../../data/nieves/expt3/gt_scenario_2_normal_50single_MoleculeList_11.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_0_mongrad_DetectionList_43.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_4_lowden_DetectionList_47.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_2_normal_50_single_DetectionList_13.parquet', '../../../data/nieves/expt3/multiple_blinking_scenar ...
# diffsig_DetectionList26.parquet', '../../../data/nieves/expt3/gt_scenario_2_normal_50single_MoleculeList_35.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_6_elliptical_w_noise_DetectionList_41.parquet', '../../../data/nieves/expt3/gt_scenario_0_mongrad_MoleculeList_43.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_8_diffden_DetectionList49.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_0_mongrad_DetectionList_17.parquet', '../../../data/nieves/expt3/gt_scenario_7_diffsig_MoleculeList_11.parquet', '../../../data/nieves/expt3/gt_scenario_4_lowden_MoleculeList_50.parquet', '../../../data/nieves/expt3/gt_scenario_0_mongrad_MoleculeList_30.parquet', '../../../data/nieves/expt3/gt_scenario_6_elliptical_w_noise_MoleculeList_23.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_6_elliptical_w_noise_DetectionList_46.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_8_diffden_DetectionList4.parquet', '../../../data/nieves/expt3/gt_scenario_8_diffden_MoleculeList_3.parquet', '../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_3.parquet', '../../../data/nieves/expt3/gt_scenario_3_normal_80single_new_MoleculeList_7.parquet', '../../../data/nieves/expt3/gt_scenario_6_elliptical_w_noise_MoleculeList_35.parquet', '../../../data/nieves/expt3/gt_scenario_3_normal_80single_new_MoleculeList_25.parquet', '../../../data/nieves/expt3/gt_scenario_3_normal_80single_new_MoleculeList_42.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_7_diffsig_DetectionList35.parquet', '../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_28.parquet', '../../../data/nieves/expt3/gt_scenario_8_diffden_MoleculeList_39.parquet', '../../../data/nieves/expt3/gt_scenario_6_elliptical_w_noise_MoleculeList_36.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_4_lowden_DetectionList_8.parquet', '../../../data/nieves/expt3/gt_scenario_0_mongrad_MoleculeList_24.parquet', '../../../data/nieves/expt3/gt_scenario_9_dsigsden_new_MoleculeList_15.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_8_diffden_DetectionList17.parquet', '../../../data/nieves/expt3/gt_scenario_0_mongrad_MoleculeList_18.parquet', '../../../data/nieves/expt3/gt_scenario_9_dsigsden_new_MoleculeList_10.parquet', '../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_49.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_8_diffden_DetectionList8.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_2_normal_50_single_DetectionList_31.parquet', '../../../data/nieves/expt3/gt_scenario_6_elliptical_w_noise_MoleculeList_18.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_6_elliptical_w_noise_DetectionList_44.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_0_mongrad_DetectionList_15.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_6_elliptical_w_noise_DetectionList_37.parquet', '../../../data/nieves/expt3/gt_scenario_0_mongrad_MoleculeList_39.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_9_dsigsden_new_DetectionList_11.parquet', '../../../data/nieves/expt3/gt_scenario_4_lowden_MoleculeList_21.parquet', '../../../data/nieves/expt3/gt_scenario_3_normal_80single_new_MoleculeList_17.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_4_lowden_DetectionList_48.parquet', '../../../data/nieves/expt3/gt_scenario_0_mongrad_MoleculeList_25.parquet', '../../../data/nieves/expt3/gt_scenario_8_diffden_MoleculeList_1.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_2_normal_50_single_DetectionList_7.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_6_elliptical_w_noise_DetectionList_45.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_3_normal_80single_new_DetectionList_17.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_7_diffsig_DetectionList44.parquet', '../../../data/nieves/expt3/multiple_blinking_scenario_2_normal_50_singl ...
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_23.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_19.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_40.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_36.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_35.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_42.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_39.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_38.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_33.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_4.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_24.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_50.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_11.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_31.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_1.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_21.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_12.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_7.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_45.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_25.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_8.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_34.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_37.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_9.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_26.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_32.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_5.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_30.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_47.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_6.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_17.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_13.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_29.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_43.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_2.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_10.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_15.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_22.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_46.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_18.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_48.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_27.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_44.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_41.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_14.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_20.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_3.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_28.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_49.parquet
#   warnings.warn(warning)
# /home/oliver/smlm_cloud/locpix-points/src/locpix_points/preprocessing/functions.py:123: UserWarning: All gt labels same for each localisation in file ../../../data/nieves/expt3/gt_scenario_1_CSR_MoleculeList_16.parquet
#   warnings.warn(warning)

# %% [markdown]
# ### Process data

# %%
# Export config variables 

config = {}

# whether to process the data as heterogeneous or homogenous
# graph
config['hetero'] = False

# train/test/val splits
config['train_ratio'] = 0.7
config['val_ratio'] = 0.1
config['test_ratio'] = 0.2

# what to load into position
# Options: xy, xyz
config['pos']= 'xy'

# what to load into features
# Options: 
config["feat"] = 'uniform'
    
# label level
# graph or node
config["label_level"] = 'node'

yaml_save_loc = os.path.join(input_folder, 'config/expt3/process.yaml')
with open(yaml_save_loc, "w") as outfile:
        yaml.dump(config, outfile)

# %%
# Run the process script 

# copy train test split from expt1

# !python ../src/locpix_points/scripts/process.py -i ../../../output/nieves/expt3 -c ../../../data/nieves/config/expt3/process.yaml -r ../../../output/nieves/expt1
# Out:
# Overwriting metadata...
# /home/oliver/smlm_cloud/locpix-points/experiments/../src/locpix_points/scripts/process.py:134: UserWarning: Known omission is if pre-transform is done to datasetthis is not currently also done to this dataset as well
#   warnings.warn("Known omission is if pre-transform is done to dataset"
# Train set...
# Processing...
# Done!
# Val set...
# Processing...
# Done!
# Test set...
# Processing...
# Done!

# %% [markdown]
# ### Train

# %%
# Export config variables 

config = {}

# device to train on (gpu or cpu)
config['gpu'] = True

# model parameters
config['model'] = "pointtransformerseg"

# optimiser parameters
config['optimiser'] ="adam"
config['lr'] = 0.001
config['weight_decay'] = 0.0001

# training parameters
config['epochs'] = 5
config['batch_size'] = 1
config['num_workers'] = 1 # generall higher -> faster
config['loss_fn'] = "nll"

config['pointtransformerseg'] = {
  "k": 16,
  "in_channels": 1,
  "out_channels": 2,
  "dim_model": [32, 64, 128, 256, 512],
  "k_up": 3, # trilinear interpolation
  "output_mlp_layers": 64,
  # ratio of points to sample when transition down
  "ratio": 0.25,
  "pos_nn_layers": 64,
  "attn_nn_layers": 64,
}

# what trying to predict
config["label_level"] = "node" # graph

# train/val transforms
# options: ['normalisescale', 'jitter', 'flip', 'randscale', 'rotate', 'shear'] # null
config["transforms"] = {
    #'jitter': 15, 
    'x_flip': None, 
    'y_flip': None, 
    #'randscale': [0.95, 1.05], 
    'z_rotate': None, 
    #'shear': 0.05, 
    'normalisescale': None
}

# wandb parameters
config["wandb_project"] = "nieves_expt3"
config["wandb_dataset"] = "nieves"

yaml_save_loc = os.path.join(input_folder, 'config/expt3/train.yaml')
with open(yaml_save_loc, "w") as outfile:
        yaml.dump(config, outfile)

# 1. Choice of augmentations

# 2. Normalise features

# %%
# Run the train script 

# !python ../src/locpix_points/scripts/train.py -i ../../../output/nieves/expt3 -c ../../../data/nieves/config/expt3/train.yaml
# Out:
# /home/oliver/mambaforge/envs/locpix_points/lib/python3.11/site-packages/torch_geometric/data/dataset.py:217: UserWarning: The `pre_filter` argument differs from the one used in the pre-processed version of this dataset. If you want to make use of another pre-fitering technique, make sure to delete '{self.processed_dir}' first
#   warnings.warn(
#
#
# ---- Params -----
#
#
# Input features:  1
# Num classes:  2
# Batch size:  1
# Epochs:  5
# Number train graphs 665
# Number val graphs 95
# wandb: Currently logged in as: oliver-umney (teststest). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /home/oliver/smlm_cloud/locpix-points/experiments/wandb/run-20230714_160526-qtknk9kl
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run toasty-blaze-1
# wandb: ⭐️ View project at https://wandb.ai/teststest/nieves_expt3
# wandb: 🚀 View run at https://wandb.ai/teststest/nieves_expt3/runs/qtknk9kl
#
#
# ---- Model summary (estimate) ----
#
#
# ======================================================================
# Layer (type:depth-idx)                        Param #
# ======================================================================
# ├─MLP: 1-1                                    --
# |    └─ReLU: 2-1                              --
# |    └─ModuleList: 2-2                        --
# |    |    └─Linear: 3-1                       64
# |    └─ModuleList: 2-3                        --
# |    |    └─BatchNorm: 3-2                    64
# ├─TransformerBlock: 1-2                       --
# |    └─Linear: 2-4                            1,056
# |    └─Linear: 2-5                            1,056
# |    └─MLP: 2-6                               --
# |    |    └─ReLU: 3-3                         --
# |    |    └─ModuleList: 3-4                   2,272
# |    |    └─ModuleList: 3-5                   --
# |    └─MLP: 2-7                               --
# |    |    └─ReLU: 3-6                         --
# |    |    └─ModuleList: 3-7                   4,192
# |    |    └─ModuleList: 3-8                   --
# |    └─PointTransformerConv: 2-8              --
# |    |    └─SumAggregation: 3-9               --
# |    |    └─MLP: 3-10                         (recursive)
# |    |    └─MLP: 3-11                         (recursive)
# |    |    └─Linear: 3-12                      1,024
# |    |    └─Linear: 3-13                      1,024
# |    |    └─Linear: 3-14                      1,024
# ├─ModuleList: 1-3                             --
# |    └─TransformerBlock: 2-9                  --
# |    |    └─Linear: 3-15                      1,056
# |    |    └─Linear: 3-16                      1,056
# |    |    └─MLP: 3-17                         2,272
# |    |    └─MLP: 3-18                         4,192
# |    |    └─PointTransformerConv: 3-19        9,536
# |    └─TransformerBlock: 2-10                 --
# |    |    └─Linear: 3-20                      4,160
# |    |    └─Linear: 3-21                      4,160
# |    |    └─MLP: 3-22                         4,352
# |    |    └─MLP: 3-23                         8,320
# |    |    └─PointTransformerConv: 3-24        24,960
# |    └─TransformerBlock: 2-11                 --
# |    |    └─Linear: 3-25                      16,512
# |    |    └─Linear: 3-26                      16,512
# |    |    └─MLP: 3-27                         8,512
# |    |    └─MLP: 3-28                         16,576
# |    |    └─PointTransformerConv: 3-29        74,240
# |    └─TransformerBlock: 2-12                 --
# |    |    └─Linear: 3-30                      65,792
# |    |    └─Linear: 3-31                      65,792
# |    |    └─MLP: 3-32                         16,832
# |    |    └─MLP: 3-33                         33,088
# |    |    └─PointTransformerConv: 3-34        246,528
# ├─ModuleList: 1-4                             --
# |    └─TransformerBlock: 2-13                 --
# |    |    └─Linear: 3-35                      4,160
# |    |    └─Linear: 3-36                      4,160
# |    |    └─MLP: 3-37                         4,352
# |    |    └─MLP: 3-38                         8,320
# |    |    └─PointTransformerConv: 3-39        24,960
# |    └─TransformerBlock: 2-14                 --
# |    |    └─Linear: 3-40                      16,512
# |    |    └─Linear: 3-41                      16,512
# |    |    └─MLP: 3-42                         8,512
# |    |    └─MLP: 3-43                         16,576
# |    |    └─PointTransformerConv: 3-44        74,240
# |    └─TransformerBlock: 2-15                 --
# |    |    └─Linear: 3-45                      65,792
# |    |    └─Linear: 3-46                      65,792
# |    |    └─MLP: 3-47                         16,832
# |    |    └─MLP: 3-48                         33,088
# |    |    └─PointTransformerConv: 3-49        246,528
# |    └─TransformerBlock: 2-16                 --
# |    |    └─Linear: 3-50                      262,656
# |    |    └─Linear: 3-51                      262,656
# |    |    └─MLP: 3-52                         33,472
# |    |    └─MLP: 3-53                         66,112
# |    |    └─PointTransformerConv: 3-54        886,016
# ├─ModuleList: 1-5                             --
# |    └─TransitionUp: 2-17                     --
# |    |    └─MLP: 3-55                         2,144
# |    |    └─MLP: 3-56                         1,120
# |    └─TransitionUp: 2-18                     --
# |    |    └─MLP: 3-57                         8,384
# |    |    └─MLP: 3-58                         4,288
# |    └─TransitionUp: 2-19                     --
# |    |    └─MLP: 3-59                         33,152
# |    |    └─MLP: 3-60                         16,768
# |    └─TransitionUp: 2-20                     --
# |    |    └─MLP: 3-61                         131,840
# |    |    └─MLP: 3-62                         66,304
# ├─ModuleList: 1-6                             --
# |    └─TransitionDown: 2-21                   --
# |    |    └─MLP: 3-63                         2,240
# |    └─TransitionDown: 2-22                   --
# |    |    └─MLP: 3-64                         8,576
# |    └─TransitionDown: 2-23                   --
# |    |    └─MLP: 3-65                         33,536
# |    └─TransitionDown: 2-24                   --
# |    |    └─MLP: 3-66                         132,608
# ├─MLP: 1-7                                    --
# |    └─ReLU: 2-25                             --
# |    └─ModuleList: 2-26                       --
# |    |    └─Linear: 3-67                      262,656
# |    └─ModuleList: 2-27                       --
# |    |    └─Identity: 3-68                    --
# ├─TransformerBlock: 1-8                       --
# |    └─Linear: 2-28                           262,656
# |    └─Linear: 2-29                           262,656
# |    └─MLP: 2-30                              --
# |    |    └─ReLU: 3-69                        --
# |    |    └─ModuleList: 3-70                  33,472
# |    |    └─ModuleList: 3-71                  --
# |    └─MLP: 2-31                              --
# |    |    └─ReLU: 3-72                        --
# |    |    └─ModuleList: 3-73                  66,112
# |    |    └─ModuleList: 3-74                  --
# |    └─PointTransformerConv: 2-32             --
# |    |    └─SumAggregation: 3-75              --
# |    |    └─MLP: 3-76                         (recursive)
# |    |    └─MLP: 3-77                         (recursive)
# |    |    └─Linear: 3-78                      262,144
# |    |    └─Linear: 3-79                      262,144
# |    |    └─Linear: 3-80                      262,144
# ├─MLP: 1-9                                    --
# |    └─ReLU: 2-33                             --
# |    └─ModuleList: 2-34                       --
# |    |    └─Linear: 3-81                      2,112
# |    |    └─Linear: 3-82                      130
# |    └─ModuleList: 2-35                       --
# |    |    └─Identity: 3-83                    --
# ======================================================================
# Total params: 4,870,658
# Trainable params: 4,870,658
# Non-trainable params: 0
# ======================================================================
#
#
# ---- Training... ----
# Epoch:  0
# Epoch:  1
# ^C
# Traceback (most recent call last):
#   File "/home/oliver/smlm_cloud/locpix-points/experiments/../src/locpix_points/scripts/train.py", line 262, in <module>
#     main()
#   File "/home/oliver/smlm_cloud/locpix-points/experiments/../src/locpix_points/scripts/train.py", line 220, in main
#     train.train_loop(
#   File "/home/oliver/smlm_cloud/locpix-points/src/locpix_points/training/train.py", line 80, in train_loop
#     scaler.scale(loss).backward()
#   File "/home/oliver/mambaforge/envs/locpix_points/lib/python3.11/site-packages/torch/_tensor.py", line 487, in backward
#     torch.autograd.backward(
#   File "/home/oliver/mambaforge/envs/locpix_points/lib/python3.11/site-packages/torch/autograd/__init__.py", line 200, in backward
#     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt
# wandb: Waiting for W&B process to finish... (failed 255). Press Control-C to abort syncing.

# %% [markdown]
# ### Evaluate

# %%
# Export config variables

# Run the evaluate script

python src/locpix_points/scripts/evaluate.py -i ../../output/nieves -c src/locpix_points/templates/evaluate.yaml

# %% [markdown]
# ### Interpret the results

# %%
# Pytorch geometric explainability tools
